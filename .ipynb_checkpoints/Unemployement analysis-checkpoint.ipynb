# %%
import pandas as pd
df=pd.load_csv("D:/All folder\Engineering\3rd year\OIBSIP\Unemployment in India (1).csv")
df.head()
# Out:
#   Cell In[1], line 2
#     df=pd.load_csv("D:\All folders\Engineering\3rd year\OIBSIP\Unemployment in India (1).csv")
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 42-43: truncated \UXXXXXXXX escape
