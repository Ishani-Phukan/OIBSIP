# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
df=pd.read_csv("C:/Users/Ishani Phukan/Downloads/Iris (1).csv")

# Initial inspection
df.shape
df.columns
df.head()
print(f"Number of unique species: {df['Species'].nunique()}")
# Out:
# Number of unique species: 3

# %%
# Replacing null values with the mean of each column and checking if there are any empty values left
df.fillna(df.mean(numeric_only=True), inplace=True)
print(df.isnull().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Label encoding the target variables
encoder=LabelEncoder()
df['Species']=encoder.fit_transform(df['Species'])
print(f"Mapping: {df['Species']}")
# Out:
# Mapping: 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int32

# %%
# Splitting features and the target
X = df.drop('Species', axis=1)
y = df['Species']

# %%
# Feature Scaling 
scaler = StandardScaler()
X = scaler.fit_transform(X)
